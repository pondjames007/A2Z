# %% [markdown]
# # Question Generator

# %%
import requests
from bs4 import BeautifulSoup
import random
from shmarkov import *

# %% [markdown]
# ### Get text from Yahoo answer

# %%
def getRandomQuestion():
    html = requests.get("https://answers.yahoo.com/answer").text
    soup = BeautifulSoup(html, 'html.parser')
    questions = soup.select(".qHead a")

    question = random.choice(questions).text
    
    return question

# %% [markdown]
# ### Put all questions in one string

# %%
text = ""
for i in range(30):
    text += getRandomQuestion() + " "
words = text.split()

# %%
text
# Out:
# "Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? How come i dont see any jews in the ghetto? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? How come i dont see any jews in the ghetto? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Should I vote Democrat or Republican? Some of my emails go directly to trash why? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? What do you think of the prosperity gospel? Some of my emails go directly to trash why? "

# %% [markdown]
# #### Make a Markov model in characters

# %% [markdown]
# ##### ngram = 2

# %%
model = markov_model(2, text)

# %%
model
# Out:
# {(' ', "'"): ['t'],
#  (' ', '-'): ['-', '-'],
#  (' ', '2'): ['C', 'C', 'C', 'C'],
#  (' ', 'A'): ['u', 'u', 'r', 'u', 'l', 'r', 'm', 'r', 'u', 'l', 'u'],
#  (' ', 'B'): ['o', 'o', 'o', 'o'],
#  (' ', 'C'): ['a', 'h', 'a', 'h', 'l', 'a', 'h', 'a', 'h'],
#  (' ', 'D'): ['a', 'o', 'o', 'o', 'o', 'o', 'o', 'e'],
#  (' ', 'H'): ['o', 'o'],
#  (' ', 'I'): [' '],
#  (' ', 'Q'): ['B', 'B', 'B', 'B'],
#  (' ', 'R'): ['e'],
#  (' ', 'S'): ['u', 'u', 'o', 'u', 'h', 'o', 'u', 'o'],
#  (' ', 'W'): ['h', 'h'],
#  (' ', 'a'): [' ',
#   'n',
#   ' ',
#   't',
#   'c',
#   'n',
#   'd',
#   ' ',
#   't',
#   'n',
#   ' ',
#   ' ',
#   'r',
#   'n',
#   'd',
#   ' ',
#   ' ',
#   't',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   't'],
#  (' ', 'b'): ['e', 'o', 'e', 'e', 'e', 'e', 'o', 'e'],
#  (' ', 'c'): ['o', 'o', 'a'],
#  (' ', 'd'): ['o', 'o', 'e', 'i', 'e', 'e', 'i', 'o', 'i'],
#  (' ', 'e'): ['n', 'm', 'n', 'x', 'n', 'n', 'n', 'n', 'm', 'm'],
#  (' ', 'f'): ['e',
#   'o',
#   'e',
#   'a',
#   'r',
#   'a',
#   'e',
#   'o',
#   'e',
#   'e',
#   'o',
#   'e',
#   'o',
#   'e',
#   'o',
#   'a',
#   'r',
#   'a',
#   'e',
#   'o'],
#  (' ', 'g'): ['h',
#   'h',
#   'h',
#   'h',
#   'o',
#   'e',
#   'o',
#   'o',
#   'h',
#   'o',
#   'e',
#   'o',
#   'h',
#   'o',
#   'o'],
#  (' ', 'h'): ['a', 'o', 'a'],
#  (' ', 'i'): ['n', ' ', 'n', ' ', 'n', 'n', 'm', 'n', 'n', 'n', 'n'],
#  (' ', 'j'): ['e', 'e'],
#  (' ', 'l'): ['e', 'i', 'e', 'e', 'e', 'e', 'e'],
#  (' ', 'm'): ['e',
#   'a',
#   'a',
#   'a',
#   'y',
#   'e',
#   'a',
#   'e',
#   'a',
#   'e',
#   'e',
#   'e',
#   'y',
#   'a',
#   'y'],
#  (' ', 'n'): ['o', 'o'],
#  (' ', 'o'): ['t',
#   'v',
#   'v',
#   'f',
#   't',
#   'v',
#   'v',
#   't',
#   'v',
#   't',
#   'v',
#   't',
#   'v',
#   't',
#   'v',
#   'r',
#   'f',
#   'f',
#   'f'],
#  (' ', 'p'): ['r'],
#  (' ', 'q'): ['u', 'u', 'u', 'u', 'u'],
#  (' ', 's'): ['e',
#   'p',
#   'p',
#   'k',
#   'p',
#   'e',
#   't',
#   'o',
#   'y',
#   'e',
#   'o',
#   'k',
#   'p',
#   't',
#   'o',
#   'y',
#   'p'],
#  (' ', 't'): ['h',
#   'r',
#   'r',
#   'a',
#   'h',
#   'a',
#   'h',
#   'e',
#   'h',
#   'h',
#   'h',
#   'r',
#   'h',
#   'h',
#   'h',
#   'h',
#   'h',
#   'o',
#   'h',
#   'o',
#   'o',
#   'r',
#   'h',
#   'r',
#   'r',
#   'a',
#   'h',
#   'a',
#   'h',
#   'e',
#   'h',
#   'o',
#   'h',
#   'h',
#   'h',
#   'h',
#   'h',
#   'r',
#   'r',
#   'a',
#   'h',
#   'a',
#   'h',
#   'e',
#   'h',
#   'h',
#   'h',
#   'r',
#   'r',
#   'a',
#   'h',
#   'a',
#   'h',
#   'e',
#   'h',
#   'r',
#   'r',
#   'a',
#   'h',
#   'a',
#   'h',
#   'e',
#   'h',
#   'o',
#   'h',
#   'o',
#   'h',
#   'r',
#   'r',
#   'a',
#   'h',
#   'a',
#   'h',
#   'e',
#   'o',
#   'r',
#   'h',
#   'h',
#   'h',
#   'h',
#   'o',
#   'r'],
#  (' ', 'v'): ['o', 'o', 'o', 'o', 'o'],
#  (' ', 'w'): ['i', 'i', 'i', 'h', 'a', 'i', 'i', 'h', 'i', 'h'],
#  (' ', 'y'): ['o'],
#  ("'", ' '): ['s'],
#  ("'", 's'): [' '],
#  ("'", 't'): ['o'],
#  ('(', 'O'): ['H', 'H'],
#  ('(', 'l'): [')', ')'],
#  ('(', 's'): [')', ')', ')', ')'],
#  (')', ' '): ['-', '-'],
#  (')', '+'): ['2', '2'],
#  (')', '2'): ['(', '('],
#  (')', '?'): [' ', ' '],
#  ('+', '2'): ['H', 'H'],
#  (',', ' '): ['i', 'i', 'i', 'i', 'i', 'i'],
#  ('-', '-'): ['-', '>', '-', '>'],
#  ('-', '>'): [' ', ' '],
#  ('.', '.'): ['.', 'h', '.', 'h'],
#  ('.', 'h'): ['o', 'o'],
#  ('0', '('): ['l', 'l'],
#  ('2', '('): ['s', 's'],
#  ('2', '0'): ['(', '('],
#  ('2', 'C'): ['a', 'a', 'a', 'a'],
#  ('2', 'H'): ['2', '2'],
#  ('>', ' '): ['2', '2'],
#  ('?', ' '): ['H',
#   'A',
#   'C',
#   'A',
#   'D',
#   'A',
#   'C',
#   'A',
#   '2',
#   'H',
#   'A',
#   'S',
#   'D',
#   '2',
#   'A',
#   'W',
#   'A',
#   'D',
#   'A',
#   'C',
#   'D',
#   'D',
#   'A',
#   'D',
#   'S',
#   'S',
#   'A',
#   'C',
#   'W',
#   'S',
#   None],
#  ('A', 'l'): ['l', 'l'],
#  ('A', 'm'): ['e'],
#  ('A', 'r'): ['e', 'e', 'e'],
#  ('A', 'u'): ['d', 'd', 'd', 'd', 'd'],
#  ('B', '?'): [' ', ' ', ' ', ' '],
#  ('B', 'o'): ['w', 'w', 'w', 'w'],
#  ('C', 'a'): ['n', 'n', 'O', '(', 'O', '(', 'n', 'n'],
#  ('C', 'h'): ['i', 'i', 'i', 'i'],
#  ('C', 'l'): ['i'],
#  ('D', 'a'): ['d'],
#  ('D', 'e'): ['m'],
#  ('D', 'o'): [' ', 'n', ' ', ' ', ' ', ' ', ' '],
#  ('H', ')'): ['2', '2'],
#  ('H', '2'): ['0', '0'],
#  ('H', 'o'): ['w', 'w'],
#  ('I', ' '): ['v'],
#  ('O', '('): ['s', 's'],
#  ('O', 'H'): [')', ')'],
#  ('Q', 'B'): ['?', '?', '?', '?'],
#  ('R', 'e'): ['p'],
#  ('S', 'h'): ['o'],
#  ('S', 'o'): ['m', 'm', 'm'],
#  ('S', 'u'): ['p', 'p', 'p', 'p'],
#  ('W', 'h'): ['o', 'a'],
#  ('a', ' '): ['f', 'g', 'g', 'v', 'f', 'f', 'g', 'f', 'f', 'v', 'f', 'g'],
#  ('a', "'"): [' '],
#  ('a', '('): ['O', 'O'],
#  ('a', 'O'): ['(', '('],
#  ('a', 'c'): ['k', 't', 'k', 'k', 'k'],
#  ('a', 'd'): [' ', 'v', 'v'],
#  ('a', 'g'): ['e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e'],
#  ('a', 'i'): ['l', 'n', 'l', 'l'],
#  ('a', 'k'): ['e',
#   'i',
#   'e',
#   'e',
#   'e',
#   'e',
#   'i',
#   'e',
#   'i',
#   'e',
#   'e',
#   'i',
#   'e',
#   'i',
#   'e',
#   'e',
#   'i',
#   'e'],
#  ('a', 'l'): ['d', 'e', 'e', 'e', 'e'],
#  ('a', 'm'): ['?', '?', '?', '?', '?', '?'],
#  ('a', 'n'): ['y',
#   ' ',
#   'y',
#   't',
#   ' ',
#   'y',
#   'g',
#   't',
#   ' ',
#   't',
#   'y',
#   't',
#   ' ',
#   '?',
#   ' '],
#  ('a', 'r'): [' ', 'e', ' '],
#  ('a', 's'): [' ', 'h', ' ', 'h', 'h'],
#  ('a', 't'): [' ', ' ', 'h', ' ', 'h', ' ', ' ', ' '],
#  ('b', ' '): ['n', 'n'],
#  ('b', 'a'): ['c', 'c', 'c', 'c'],
#  ('b', 'e'): ['s', 's', 's', 's', 's', 's'],
#  ('b', 'l'): ['i'],
#  ('b', 'o'): ['m', 'm'],
#  ('c', 'a'): ["'", 'n', 'n'],
#  ('c', 'i'): ['t', 't'],
#  ('c', 'k'): [' ', ' ', ' ', ' '],
#  ('c', 'l'): ['u', 'u', 'u', 'u', 'u', 'u'],
#  ('c', 'o'): ['m', 'm'],
#  ('c', 'r'): ['a'],
#  ('c', 't'): ['s', 'l', 'l', 'l'],
#  ('d', ' '): ['a', 't', 'f', 'f', 'I'],
#  ('d', '?'): [' '],
#  ('d', 'e'): ['m', 'r', 'm'],
#  ('d', 'i'): ['n',
#   'o',
#   'o',
#   'o',
#   'r',
#   'n',
#   'n',
#   'o',
#   'n',
#   'n',
#   'n',
#   'r',
#   'o',
#   'r'],
#  ('d', 'o'): ['n', 'n', ' '],
#  ('d', 'v'): ['a', 'a'],
#  ('e', ' '): ['b',
#   'o',
#   'm',
#   't',
#   'i',
#   'a',
#   'g',
#   'C',
#   't',
#   'S',
#   'D',
#   't',
#   'a',
#   's',
#   'C',
#   't',
#   'S',
#   'i',
#   'a',
#   'g',
#   's',
#   'b',
#   't',
#   'd',
#   'o',
#   'b',
#   'o',
#   'm',
#   't',
#   't',
#   'C',
#   't',
#   't',
#   'a',
#   's',
#   'b',
#   'o',
#   'm',
#   't',
#   'C',
#   't',
#   'S',
#   'b',
#   'o',
#   'm',
#   't',
#   'b',
#   'o',
#   'm',
#   't',
#   's',
#   'b',
#   't',
#   'd',
#   'b',
#   'o',
#   'm',
#   't',
#   'D',
#   'o',
#   'C',
#   't',
#   'S',
#   'p',
#   'o'],
#  ('e', ','): [' ', ' ', ' ', ' ', ' ', ' '],
#  ('e', '?'): [' ', ' ', ' ', ' ', ' '],
#  ('e', 'a'): ['m', 'm', 'm', 'm', 'm', 'm'],
#  ('e', 'c'): ['t', 't', 't'],
#  ('e', 'd'): [' ', '?', ' '],
#  ('e', 'e'): [' ', ' ', ' '],
#  ('e', 'f'): ['s', 's', 's', 's'],
#  ('e', 'l'): ['?'],
#  ('e', 'm'): ['a', 's', 'a', ' ', 'a', 's', 'o', 'a', 'a'],
#  ('e', 'n'): ['j', 's', ' ', 'j', 'j', 'j', 'j', 's', ' ', 'j'],
#  ('e', 'p'): ['u'],
#  ('e', 'r'): [' ',
#   ' ',
#   ' ',
#   'e',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'a',
#   'i',
#   'e',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'i'],
#  ('e', 's'): ['t',
#   's',
#   't',
#   't',
#   ' ',
#   't',
#   'e',
#   't',
#   's',
#   ' ',
#   't',
#   's',
#   't',
#   't',
#   's',
#   't',
#   's',
#   'e',
#   't',
#   's',
#   't'],
#  ('e', 't'): ['t',
#   't',
#   't',
#   't',
#   't',
#   ' ',
#   't',
#   't',
#   't',
#   't',
#   't',
#   ' ',
#   't',
#   't'],
#  ('e', 'w'): [' ', 's', 's', ' ', ' ', ' ', ' ', ' '],
#  ('e', 'x'): ['p'],
#  ('e', 'y'): [' ', ' '],
#  ('f', ' '): ['m', 'm', 't', 'm'],
#  ('f', 'a'): ['k', 'r', 'k', 'r'],
#  ('f', 'e'): ['w', 'm', 'w', 'm', 'w', 'w', 'w', 'w'],
#  ('f', 'o'): ['r', 'r', 'r', 'r', 'r', 'r'],
#  ('f', 'r'): ['i', 'i'],
#  ('f', 's'): [' ', ' ', ' ', ' '],
#  ('g', ' '): ['o',
#   't',
#   'a',
#   'q',
#   'q',
#   'q',
#   'o',
#   't',
#   'a',
#   'o',
#   't',
#   'a',
#   'q',
#   'o',
#   't',
#   'a',
#   'o',
#   't',
#   'a',
#   'o',
#   't',
#   'a',
#   'q'],
#  ('g', 'e'): [',',
#   's',
#   'd',
#   'n',
#   't',
#   ',',
#   'd',
#   's',
#   ',',
#   ',',
#   ',',
#   'd',
#   'n',
#   't',
#   ','],
#  ('g', 'g'): ['e', 'e'],
#  ('g', 'h'): ['e', 'e', 'e', 'e', 'e', 'e'],
#  ('g', 'o'): [' ', ' ', ' ', ' ', ' ', 's', ' '],
#  ('h', ' '): ['a', 'a', 'w', 'a', 'w', 'a', 'w'],
#  ('h', 'a'): ['s', 's', 't'],
#  ('h', 'e'): [' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   't',
#   ' ',
#   ' ',
#   't',
#   'r',
#   ' ',
#   ' ',
#   't',
#   ' ',
#   't',
#   's',
#   ' ',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   'm',
#   'y',
#   'y',
#   'r',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   't',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   's',
#   ' ',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   't',
#   ' '],
#  ('h', 'i'): ['e', 'e', 'e', 'e', 'n'],
#  ('h', 'o'): ['w', ' ', 'w', 'w', 'u'],
#  ('h', 'y'): ['.', '?', '.', '?', '?'],
#  ('i', ' '): ['d', 'd'],
#  ('i', 'c'): ['i', 'a', 'i', 'a'],
#  ('i', 'e'): ['f', 'f', 'f', 'f'],
#  ('i', 'g'): ['g', 'g'],
#  ('i', 'k'): ['e'],
#  ('i', 'l'): ['l', 's', 'l', 's', 's'],
#  ('i', 'm'): ['p'],
#  ('i', 'n'): ['g',
#   'c',
#   'g',
#   'g',
#   ' ',
#   'g',
#   'g',
#   ' ',
#   'g',
#   ' ',
#   'g',
#   'c',
#   'g',
#   'g',
#   't',
#   ' ',
#   ' ',
#   'g',
#   'c',
#   'g',
#   'g',
#   'g',
#   'g',
#   'c',
#   'g',
#   'g',
#   'g',
#   'c',
#   'g',
#   'g',
#   'g',
#   'c',
#   'g',
#   'g',
#   'g',
#   'k'],
#  ('i', 'o'): [' ', 'n', ' ', 'n', ' ', 'n', ' ', 'n', ' ', 'n'],
#  ('i', 'r'): ['e', 'e', 'e'],
#  ('i', 't'): ['t', 'h', 't', 'h', 't', ' ', 't', 'h', ' ', 't', 'h', 'y'],
#  ('j', 'e'): ['w', 'w'],
#  ('j', 'o'): ['y', 'y', 'y', 'y', 'y', 'y'],
#  ('k', ' '): ['a', 'a', 'a', 'a', 'o'],
#  ('k', 'e'): [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ('k', 'i'): ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n'],
#  ('l', ' '): ['w', 'w', 't', 't', 'w', 't', 't', 'w'],
#  ('l', ')'): [' ', ' '],
#  ('l', '?'): [' '],
#  ('l', 'a'): ['i'],
#  ('l', 'd'): [' ', ' '],
#  ('l', 'e'): ['t', ' ', '?', 't', ' ', '?', 't', 't', 't', 't'],
#  ('l', 'i'): ['t', 't', 'k', 't', 'c', 'n', 't', 'c', 'c', 't'],
#  ('l', 'l'): ['s',
#   's',
#   ' ',
#   ' ',
#   's',
#   's',
#   's',
#   's',
#   's',
#   's',
#   's',
#   's',
#   ' ',
#   ' ',
#   's',
#   's'],
#  ('l', 's'): [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  ('l', 'u'): ['d', 'd', 'd', 'd', 'd', 'd'],
#  ('l', 'y'): [' ', ' ', ' '],
#  ('m', ' '): ["'"],
#  ('m', '?'): [' ', ' ', ' ', ' ', ' ', ' '],
#  ('m', 'a'): ['k', 'l', 'l', 'k', 'i', 'l', 'l', 'k', 'i', 'k', 'i'],
#  ('m', 'b'): [' ', ' '],
#  ('m', 'e'): ['s', ' ', ' ', ' ', 's', 'r', 's', 's', 's', 's', ' ', ' '],
#  ('m', 'o'): ['c'],
#  ('m', 'p'): ['?', 'a', 'o', 'a'],
#  ('m', 's'): [' ', ' '],
#  ('m', 'y'): [' ', ' ', ' '],
#  ('n', ' '): ['t', 't', 'h', 't', 't', 'f', 'e', 'h', 'h', 't', 'f', 't'],
#  ('n', "'"): ['s'],
#  ('n', '?'): [' ', ' ', ' ', ' ', ' ', ' '],
#  ('n', 'a'): ['l'],
#  ('n', 'c'): ['l', 'l', 'l', 'l', 'l', 'l'],
#  ('n', 'g'): [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'e',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  ('n', 'j'): ['o', 'o', 'o', 'o', 'o', 'o'],
#  ('n', 'k'): [' '],
#  ('n', 'o'): ['n', 'n'],
#  ('n', 's'): ['e', 'e', 'e', 'e'],
#  ('n', 't'): [' ', 'a', ' ', 'o', 's', ' ', 'a'],
#  ('n', 'y'): [' ', ' ', ' ', ' '],
#  ('o', ' '): ['t',
#   's',
#   's',
#   's',
#   's',
#   't',
#   'g',
#   'd',
#   't',
#   't',
#   'w',
#   'g',
#   's',
#   't',
#   't',
#   's',
#   't',
#   't',
#   's',
#   't',
#   'g',
#   't',
#   'd',
#   't',
#   's',
#   'y',
#   'd',
#   't'],
#  ('o', '?'): [' ', ' '],
#  ('o', 'b'): ['a', 'a', 'a', 'a'],
#  ('o', 'c'): ['r'],
#  ('o', 'f'): [' ', ' ', ' ', ' '],
#  ('o', 'l'): ['l',
#   'l',
#   'i',
#   'l',
#   'l',
#   'l',
#   'l',
#   'l',
#   'l',
#   'l',
#   'l',
#   'i',
#   'l',
#   'l'],
#  ('o', 'm'): ['e', 'e', 'b', 'e', 'b', 'e', 'e'],
#  ('o', 'n'): ['t', '?', '?', 'a', '?', 't', 's', "'", '?', 's', '?'],
#  ('o', 'r'): [' ', ' ', 't', ' ', ' ', ' ', ' ', ' '],
#  ('o', 's'): ['p', 'p'],
#  ('o', 't'): ['h', 'e', 'e', 'h', 'h', 'h', 'h', 'e', 'e', 'h', 'e'],
#  ('o', 'u'): ['r', 'l', ' '],
#  ('o', 'v'): ['e', 'e', 'e', 'e', 'e', 'e', 'e', 'e'],
#  ('o', 'w'): [' ', 'l', 'l', ' ', ' ', ' ', 'l', ' ', 'l'],
#  ('o', 'y'): [' ', ' ', ' ', ' ', ' ', ' '],
#  ('p', '?'): [' '],
#  ('p', 'a'): ['t', 't'],
#  ('p', 'e'): ['r', 'r', 'r', 'r', 'r', 'l'],
#  ('p', 'l'): ['i', 'i', 'i', 'a', 'i', 'i'],
#  ('p', 'o'): ['r'],
#  ('p', 'r'): ['o'],
#  ('p', 'u'): ['b'],
#  ('q', 'u'): ['e', 'e', 'e', 'e', 'e'],
#  ('r', ' '): ['t',
#   't',
#   't',
#   'B',
#   'm',
#   'B',
#   's',
#   'w',
#   't',
#   't',
#   't',
#   'A',
#   'm',
#   't',
#   't',
#   't',
#   'B',
#   't',
#   't',
#   't',
#   't',
#   't',
#   't',
#   's',
#   'w',
#   't',
#   't',
#   't',
#   'R',
#   'B'],
#  ('r', 'a'): ['s', 'n', 't', 's', 's'],
#  ('r', 'e'): [' ', ' ', 'c', ' ', '?', ' ', ' ', 'c', 'c'],
#  ('r', 'i'): ['g', 'c', 'g', 't'],
#  ('r', 'o'): ['l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 's'],
#  ('r', 't'): ['a'],
#  ('r', 'u'): ['m'],
#  ('s', ' '): ['e',
#   't',
#   'i',
#   'm',
#   'l',
#   'f',
#   'o',
#   'm',
#   'i',
#   'g',
#   'g',
#   'e',
#   't',
#   'd',
#   't',
#   'f',
#   'o',
#   'e',
#   't',
#   'm',
#   'e',
#   't',
#   'e',
#   't',
#   'g',
#   'e',
#   't',
#   'g',
#   'm',
#   'g'],
#  ('s', ')'): ['+', '?', '+', '?'],
#  ('s', 'a'): ['g', 'g', 'g', 'g', 'g', 'g'],
#  ('s', 'e'): ['e', 'e', ' ', 'n', ' ', 'e', ' ', 'n', ' '],
#  ('s', 'h'): [' ', ' ', ' '],
#  ('s', 'k'): ['i', 'i'],
#  ('s', 'o'): ['l', ' ', 'l'],
#  ('s', 'p'): ['l', 'l', 'l', 'l', 'l', 'e', 'e'],
#  ('s', 's'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('s', 't'): [' ', 'i', 'i', 'i', 'a', ' ', ' ', 'i', ' ', ' ', 'a', ' ', 'i'],
#  ('s', 'y'): ['m', 'm'],
#  ('t', ' '): ['t',
#   's',
#   'Q',
#   'Q',
#   's',
#   'v',
#   'a',
#   't',
#   't',
#   't',
#   'Q',
#   't',
#   't',
#   'v',
#   'a',
#   't',
#   'o',
#   'Q',
#   'd'],
#  ('t', 'a'): ['k',
#   'k',
#   'g',
#   'g',
#   'k',
#   'k',
#   'n',
#   'g',
#   'k',
#   'k',
#   'k',
#   'k',
#   'k',
#   'k',
#   'g',
#   'k',
#   'k'],
#  ('t', 'e'): ['a', 'r', '?', 'a', 'a', 'a', 'a', 'r', '?', 'a', ' '],
#  ('t', 'h'): ['e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   ' ',
#   'e',
#   'e',
#   'e',
#   ' ',
#   'e',
#   'e',
#   'y',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   ' ',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'y',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   ' ',
#   'i',
#   'e'],
#  ('t', 'i'): ['n',
#   'n',
#   'o',
#   'n',
#   'o',
#   'n',
#   'o',
#   'n',
#   'n',
#   'n',
#   'o',
#   'n',
#   'n',
#   'n',
#   'n',
#   'o'],
#  ('t', 'l'): ['y', 'y', 'y'],
#  ('t', 'o'): ['?',
#   'b',
#   'b',
#   '?',
#   ' ',
#   ' ',
#   ' ',
#   'n',
#   ' ',
#   'u',
#   'b',
#   ' ',
#   ' ',
#   ' ',
#   'b',
#   ' '],
#  ('t', 'r'): ['o',
#   'o',
#   'u',
#   'a',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'a',
#   'a'],
#  ('t', 's'): [' ', ' '],
#  ('t', 't'): ['i',
#   'o',
#   'i',
#   'o',
#   'i',
#   'o',
#   'i',
#   'o',
#   'i',
#   'i',
#   'i',
#   'o',
#   'i',
#   'i',
#   'i',
#   'i',
#   'o'],
#  ('t', 'y'): [' '],
#  ('u', ' '): ['t'],
#  ('u', 'b'): ['l'],
#  ('u', 'd'): ['i', 'i', 'i', 'i', 'i', 'i', 'i', 'i', 'i', 'i', 'i'],
#  ('u', 'e'): ['s', 's', 's', 's', 's'],
#  ('u', 'l'): ['d'],
#  ('u', 'm'): ['p'],
#  ('u', 'p'): ['e', 'e', 'e', 'e'],
#  ('u', 'r'): [' '],
#  ('v', 'a'): ['n', 'n'],
#  ('v', 'e'): ['r', 'r', 'r', 'r', 'r', 'r', 'r', 'r'],
#  ('v', 'o'): ['t', 't', 't', 't', 't'],
#  ('w', ' '): ['f', 'c', 'c', 'f', 'f', 'i', 'f', 'f', 'f', 'f', 'f'],
#  ('w', 'a'): ['n'],
#  ('w', 'h'): ['y', 'y', 'y'],
#  ('w', 'i'): ['t', 't', 'l', 't', 'l', 't'],
#  ('w', 'l'): [' ', ' ', ' ', ' '],
#  ('w', 's'): [' ', ' '],
#  ('x', 'p'): ['l'],
#  ('y', ' '): ['l',
#   'j',
#   'a',
#   'j',
#   'e',
#   't',
#   'l',
#   'c',
#   'a',
#   'a',
#   'l',
#   'l',
#   'l',
#   'l',
#   'e',
#   't',
#   'g',
#   'e',
#   't'],
#  ('y', '.'): ['.', '.'],
#  ('y', '?'): [' ', ' ', ' '],
#  ('y', 'm'): ['p', 'p'],
#  ('y', 'o'): ['u']}

# %%
for i in range(10):
    output_text = "".join(gen_from_model(2, model))
    print("Question " + str(i+1) +": " +output_text)
# Out:
# Question 1: n? Are trolls emaking over ter the ther my ad trash a vothe toback over Bow ing a ghetting questink ov
# Question 2:  enjoy emaletting othy? Clittoback a femalettincludio st trolls to sting a ghe splin explittoback athe
# Question 3: ittoback over Bowl team? Can the go to the to do go se Super the trolls en takincludio taking the the
# Question 4: imp? Chiefs enjoy a for thiefs mer take Super the a fortagest QB? Audio ghe besting to sking over witt
# Question 5: crantake othe trolit take a go tagestakin trolls few frity a fems mald the or the bes enjoy lettionald
# Question 6: joy letto gherash why? Are ack antaged? 2CaO(s)? 2Cany a ghet the thest QB? Super me my ad fews make t
# Question 7:  CaO(s)? Auding trolls over trolitto take trolls mest trosplicit QB? How far the the a vothe trolls le
# Question 8: ire the bome Do splicit a fews over themaletting at th ang questionalettio the of maletting over Bowl
# Question 9: ettionsee skincludiontoback at thy? Are ing othe bomest troll trolls of to thet vothe Superath at dont
# Question 10: frica' splitting thettin enjoy jew for wils enjoy go trump? Audire oth why....hour Bow comb non? Audio

# %% [markdown]
# ##### ngram = 5

# %%
model = markov_model(5, text)

# %%
for i in range(10):
    output_text = "".join(gen_from_model(5, model))
    print("Question " + str(i+1) +": " +output_text)
# Out:
# Question 1: y emails go to get a vote? Some of my emails go to go see any jews in the best trolls enjoy letting quest
# Question 2:  other trolls enjoy letting other trolls enjoy letting other trolls take over the Chiefs make them 'tour
# Question 3: 's deranged? Who wants to go see any jews in the dems go directly to trash why? Do the message, including
# Question 4: ing a few for the dems go directly to trash why?
# Question 5: of my emails go directly to trash why? Audio splitting other trolls take over male? Do the Super Bowl wit
# Question 6: ? Do they are? Are the best trolls take over the ghetto? Audio splitting question? Can the Super Bowl wit
# Question 7: d acts like Donald trump? Are the best trolls take over the best trolls enjoy letting question? Can the b
# Question 8: m? Should I vote? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trol
# Question 9: in how important they are? Are the dems go directly to trash why? Do the team? Do the team? Should I vote
# Question 10: All the Clinton's deranged? Who wants to go see the Super Bowl with a ghetto? Audio splitting other troll

# %% [markdown]
# #### Make a Markov model in words

# %% [markdown]
# ##### ngram = 2

# %%
word_model = markov_model(2, words)

# %%
word_model
# Out:
# {("'tour", "America'"): ['so'],
#  ('--->', '2Ca(OH)2(s)?'): ['How', 'Are'],
#  ('2Ca(OH)2(s)?', 'Are'): ['the'],
#  ('2Ca(OH)2(s)?', 'How'): ['come'],
#  ('2CaO(s)+2H20(l)', '--->'): ['2Ca(OH)2(s)?', '2Ca(OH)2(s)?'],
#  ('All', 'these'): ['staged', 'staged'],
#  ("America'", 'so'): ['they'],
#  ('Are', 'the'): ["Clinton's"],
#  ('Are', 'there'): ['any', 'any'],
#  ('Audio', 'splitting'): ['question?',
#   'question?',
#   'question?',
#   'question?',
#   'question?'],
#  ('Bowl', 'with'): ['a', 'a', 'a', 'a'],
#  ('Can', 'the'): ['Chiefs', 'Chiefs', 'Chiefs', 'Chiefs'],
#  ('Chiefs', 'make'): ['the', 'the', 'the', 'the'],
#  ("Clinton's", 'deranged?'): ['Who'],
#  ('Dad', 'acts'): ['like'],
#  ('Democrat', 'or'): ['Republican?'],
#  ('Do', 'the'): ['best', 'best', 'best', 'best', 'best', 'best'],
#  ('Donald', 'trump?'): ['Are'],
#  ('How', 'come'): ['i', 'i'],
#  ('I', 'vote'): ['Democrat'],
#  ('QB?', 'Audio'): ['splitting', 'splitting'],
#  ('QB?', 'Do'): ['the'],
#  ('QB?', 'What'): ['do'],
#  ('Republican?', 'Some'): ['of'],
#  ('Should', 'I'): ['vote'],
#  ('Some', 'of'): ['my', 'my', 'my'],
#  ('Super', 'Bowl'): ['with', 'with', 'with', 'with'],
#  ('What', 'do'): ['you'],
#  ('Who', 'wants'): ['to'],
#  ('a', 'few'): ['for', 'for', 'for', 'for', 'for', 'for'],
#  ('a', 'ghettoback'): ['at', 'at', 'at', 'at'],
#  ('a', 'vote?'): ['Some', 'Do'],
#  ('acts', 'like'): ['Donald'],
#  ('advantages', 'female'): ['skin', 'skin'],
#  ('any', 'advantages'): ['female', 'female'],
#  ('any', 'jews'): ['in', 'in'],
#  ('are?', 'Are'): ['there'],
#  ('at', 'QB?'): ['Audio', 'Audio', 'Do', 'What'],
#  ('best', 'trolls'): ['enjoy', 'enjoy', 'enjoy', 'enjoy', 'enjoy', 'enjoy'],
#  ('bomb', 'nonsense'): ['to', 'to'],
#  ('can', 'explain'): ['how'],
#  ('come', 'i'): ['dont', 'dont'],
#  ('dems', 'go'): ['to', 'to'],
#  ('deranged?', 'Who'): ['wants'],
#  ('directly', 'to'): ['trash', 'trash', 'trash'],
#  ('do', 'you'): ['think'],
#  ('dont', 'see'): ['any', 'any'],
#  ('emails', 'go'): ['directly', 'directly', 'directly'],
#  ('enjoy', 'letting'): ['other', 'other', 'other', 'other', 'other', 'other'],
#  ('explain', 'how'): ['important'],
#  ('fake', 'bomb'): ['nonsense', 'nonsense'],
#  ('far', 'will'): ['the', 'the'],
#  ('female', 'skin'): ['has', 'has'],
#  ('few', 'for'): ['the', 'the', 'the', 'the', 'the', 'the'],
#  ('for', 'the'): ['team?', 'team?', 'team?', 'team?', 'team?', 'team?'],
#  ('friggen', 'far'): ['will', 'will'],
#  ('get', 'a'): ['vote?', 'vote?'],
#  ('ghetto?', 'All'): ['these'],
#  ('ghetto?', 'Audio'): ['splitting'],
#  ('ghettoback', 'at'): ['QB?', 'QB?', 'QB?', 'QB?'],
#  ('go', 'directly'): ['to', 'to', 'to'],
#  ('go', 'see'): ['them'],
#  ('go', 'to'): ['get', 'get'],
#  ('gospel?', 'Some'): ['of'],
#  ('has', 'over'): ['male?', 'male?'],
#  ('how', 'important'): ['they'],
#  ('i', 'dont'): ['see', 'see'],
#  ('important', 'they'): ['are?'],
#  ('in', 'the'): ['ghetto?', 'ghetto?'],
#  ('including', 'taking'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('jews', 'in'): ['the', 'the'],
#  ('letting', 'other'): ['trolls',
#   'trolls',
#   'trolls',
#   'trolls',
#   'trolls',
#   'trolls'],
#  ('like', 'Donald'): ['trump?'],
#  ('make', 'the'): ['Super', 'Super', 'Super', 'Super'],
#  ('male?', 'Can'): ['the'],
#  ('male?', 'Do'): ['the'],
#  ('message,', 'including'): ['taking',
#   'taking',
#   'taking',
#   'taking',
#   'taking',
#   'taking'],
#  ('my', 'emails'): ['go', 'go', 'go'],
#  ('nonsense', 'to'): ['solicit', 'solicit'],
#  ('of', 'my'): ['emails', 'emails', 'emails'],
#  ('of', 'the'): ['prosperity'],
#  ('or', 'Republican?'): ['Some'],
#  ('other', 'trolls'): ['take', 'take', 'take', 'take', 'take', 'take'],
#  ('over', 'male?'): ['Can', 'Do'],
#  ('over', 'the'): ['message,',
#   'message,',
#   'message,',
#   'message,',
#   'message,',
#   'message,'],
#  ('prosperity', 'gospel?'): ['Some'],
#  ('question?', '2CaO(s)+2H20(l)'): ['--->'],
#  ('question?', 'Can'): ['the', 'the', 'the'],
#  ('question?', 'Dad'): ['acts'],
#  ('see', 'any'): ['jews', 'jews'],
#  ('see', 'them'): ["'tour"],
#  ('skin', 'has'): ['over', 'over'],
#  ('so', 'they'): ['can'],
#  ('solicit', 'voter'): ['sympathy...how', 'sympathy...how'],
#  ('splitting', 'question?'): ['Can', 'Dad', '2CaO(s)+2H20(l)', 'Can', 'Can'],
#  ('staged', 'fake'): ['bomb', 'bomb'],
#  ('sympathy...how', 'friggen'): ['far', 'far'],
#  ('take', 'over'): ['the', 'the', 'the', 'the', 'the', 'the'],
#  ('taking', 'a'): ['few', 'few', 'few', 'few', 'few', 'few'],
#  ('team?', '2CaO(s)+2H20(l)'): ['--->'],
#  ('team?', 'All'): ['these'],
#  ('team?', 'Audio'): ['splitting'],
#  ('team?', 'Do'): ['the'],
#  ('team?', 'How'): ['come'],
#  ('team?', 'Should'): ['I'],
#  ('the', 'Chiefs'): ['make', 'make', 'make', 'make'],
#  ('the', "Clinton's"): ['deranged?'],
#  ('the', 'Super'): ['Bowl', 'Bowl', 'Bowl', 'Bowl'],
#  ('the', 'best'): ['trolls', 'trolls', 'trolls', 'trolls', 'trolls', 'trolls'],
#  ('the', 'dems'): ['go', 'go'],
#  ('the', 'ghetto?'): ['Audio', 'All'],
#  ('the', 'message,'): ['including',
#   'including',
#   'including',
#   'including',
#   'including',
#   'including'],
#  ('the', 'prosperity'): ['gospel?'],
#  ('the', 'team?'): ['How', '2CaO(s)+2H20(l)', 'Audio', 'Do', 'All', 'Should'],
#  ('them', "'tour"): ["America'"],
#  ('there', 'any'): ['advantages', 'advantages'],
#  ('these', 'staged'): ['fake', 'fake'],
#  ('they', 'are?'): ['Are'],
#  ('they', 'can'): ['explain'],
#  ('think', 'of'): ['the'],
#  ('to', 'get'): ['a', 'a'],
#  ('to', 'go'): ['see'],
#  ('to', 'solicit'): ['voter', 'voter'],
#  ('to', 'trash'): ['why?', 'why?', 'why?'],
#  ('trash', 'why?'): ['Do', 'Audio', None],
#  ('trolls', 'enjoy'): ['letting',
#   'letting',
#   'letting',
#   'letting',
#   'letting',
#   'letting'],
#  ('trolls', 'take'): ['over', 'over', 'over', 'over', 'over', 'over'],
#  ('trump?', 'Are'): ['there'],
#  ('vote', 'Democrat'): ['or'],
#  ('vote?', 'Do'): ['the'],
#  ('vote?', 'Some'): ['of'],
#  ('voter', 'sympathy...how'): ['friggen', 'friggen'],
#  ('wants', 'to'): ['go'],
#  ('why?', 'Audio'): ['splitting'],
#  ('why?', 'Do'): ['the'],
#  ('will', 'the'): ['dems', 'dems'],
#  ('with', 'a'): ['ghettoback', 'ghettoback', 'ghettoback', 'ghettoback'],
#  ('you', 'think'): ['of']}

# %%
for i in range(10):
    output_text = " ".join(gen_from_model(2, word_model))
    print("Question "+ str(i+1)+": " +output_text+"\n")
# Out:
# Question 1: team? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why?
#
# Question 2: What do you think of the prosperity gospel? Some of my emails go directly to trash why? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Should I vote
#
# Question 3: far will the dems go to get a vote? Some of my emails go directly to trash why?
#
# Question 4: male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Should I vote Democrat or Republican? Some of my emails go directly to trash why?
#
# Question 5: All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why?
#
# Question 6: team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? What do you think of the prosperity gospel? Some of my emails go directly to trash why?
#
# Question 7: the ghetto? Audio splitting question? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? How come i dont see any jews in the ghetto? All these staged fake bomb nonsense to
#
# Question 8: the ghetto? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Can the
#
# Question 9: there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they
#
# Question 10: the Super Bowl with a ghettoback at QB? Audio splitting question? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? How come i dont see any jews in the ghetto? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Do the best trolls enjoy

# %% [markdown]
# ##### ngram = 5

# %%
word_model = markov_model(5, words)

# %%
for i in range(10):
    output_text = " ".join(gen_from_model(5, word_model))
    print("Question "+ str(i+1)+": " +output_text+"\n")
# Out:
# Question 1: Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best
#
# Question 2: over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? What do you think of the prosperity gospel? Some of my emails go directly to trash why? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Do the best trolls enjoy letting other trolls
#
# Question 3: they can explain how important they are? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? How come i dont see any jews in the ghetto? All these
#
# Question 4: to get a vote? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they
#
# Question 5: emails go directly to trash why? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few
#
# Question 6: Super Bowl with a ghettoback at QB? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? All these staged fake bomb nonsense to solicit voter sympathy...how friggen far will the dems go to get a vote? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Audio splitting question? Can the Chiefs make the Super Bowl with a
#
# Question 7: America' so they can explain how important they are? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? Dad acts like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? What do you think of the prosperity gospel? Some of my emails go directly to trash why? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Audio splitting question? Can the Chiefs make the Super Bowl
#
# Question 8: to get a vote? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? Are the Clinton's deranged? Who wants to go see them 'tour America' so they can explain how important they are? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Should I vote Democrat or Republican? Some of my emails go directly to trash why?
#
# Question 9: Dad acts like Donald trump? Are there any advantages female skin has over male? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? How come i dont see any jews in the ghetto? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Audio splitting question? 2CaO(s)+2H20(l) ---> 2Ca(OH)2(s)? How come i dont see any jews in the ghetto? Audio splitting question? Can the Chiefs make the Super Bowl with a ghettoback at QB? Do the best trolls enjoy letting other trolls take over the message, including taking a few
#
# Question 10: like Donald trump? Are there any advantages female skin has over male? Can the Chiefs make the Super Bowl with a ghettoback at QB? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? Do the best trolls enjoy letting other trolls take over the message, including taking a few for the team? All these staged fake bomb
